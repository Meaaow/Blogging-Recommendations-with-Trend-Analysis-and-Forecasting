# %%
import re
import operator
import pandas as pd
import numpy as np
import json
import io
import datetime as dt
import string
import unicodedata
from collections import Counter


import nltk
import spacy
import en_core_web_sm
from spacy import displacy
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()
stopword_list = nltk.corpus.stopwords.words('english')
nlp = spacy.load('en_core_web_sm')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora, models, similarities

pd.set_option('display.max_rows', 5000)

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, RelationsOptions, CategoriesOptions
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/prachi.agrawal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/prachi.agrawal/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ## Read file of test tweets

# %%
df = pd.read_csv('Tweets.csv')
print('Number of observations are: '+str(len(df)))
# Out:
# Number of observations are: 14640

# %%
#remove any rows that has no tweet text
df = df.text.dropna()
df = df.reset_index(drop=True)
print('Number of observations are: '+str(len(df)))
# Out:
# Number of observations are: 14640

# %% [markdown]
# ## Cleaning of test tweets

# %%
def strip_links(text):
    link_regex    = re.compile('((https?):((//)|(\\\\))+([\w\d:#@%/;$()~_?\+-=\\\.&](#!)?)*)', re.DOTALL)
    links         = re.findall(link_regex, text)
    for link in links:
        text = text.replace(link[0], ', ')    
    return text

def strip_mentions(text):
    entity_prefixes = ['@']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

def strip_hashtags(text):
    entity_prefixes = ['#']
    for separator in  string.punctuation:
        if separator not in entity_prefixes :
            text = text.replace(separator,' ')
    words = []
    for word in text.split():
        word = word.strip()
        if word:
            if word[0] not in entity_prefixes:
                words.append(word)
    return ' '.join(words)

# %%
for i in range(0,len(df)):
    df[i]=strip_links(df[i])
for i in range(0,len(df)):
    df[i]=strip_mentions(df[i])
for i in range(0,len(df)):
    df[i]=strip_hashtags(df[i])
for i in range(0,len(df)):
    df[i] = df[i].replace('RT', '')

# %%
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "youyou will",
  "you'll've": "you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    def replace(match):
        return cList[match.group(0)]
    text = c_re.sub(replace, text.lower())
    return text

def remove_special_characters(text, remove_digits=False):
    pattern = r'[^a-zA-z0-9\s]' if not remove_digits else r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    return text

def remove_stopwords(text, is_lower_case=False):
    tokens = tokenizer.tokenize(text)
    tokens = [token.strip() for token in tokens]
    if is_lower_case:
        filtered_tokens = [token for token in tokens if token not in stopword_list]
    else:
        filtered_tokens = [token for token in tokens if token.lower() not in stopword_list]
    filtered_text = ' '.join(filtered_tokens)    
    return filtered_text

# %%
for i in range(0,len(df)):
    df[i]=expandContractions(df[i])
for i in range(0,len(df)):
    df[i]=remove_special_characters(df[i], remove_digits=True)
# for i in range(0,len(df)):
#     df[i]=remove_stopwords(df[i])

df.replace('', np.nan, inplace=True)
df.dropna(inplace=True)
#df.to_csv("cleaned_tweets.csv", header = False, index=False)

# %% [markdown]
# ## Get Categories and Segregate test tweets into 4 files of test tweets

# %%
natural_language_understanding = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    iam_apikey='KN0q1fJW6X-YrL9xgmyqgl-TUohn3sWNYGnk7HJz-IPY',
    url='https://gateway.watsonplatform.net/natural-language-understanding/api'
)

health = []
entertainment = []
food = []
politics = [] 
sports = [] 

for i in range(0,len(df)):
    try:
        
        if len(df[i]) < 15 or len(df[i].split(" ")) < 3:
            continue

        response = natural_language_understanding.analyze(
            text= df[i] ,
            features=Features(categories=CategoriesOptions())
        ).get_result()

        if 'categories' not in response:
            continue

        if len(response["categories"]) == 0:
            continue

        data = response["categories"][0]['label']

        if len(data) >= 1:
            category = data.split("/")[1]

            if category == "health and fitness":
                health.append(df[i])
            elif category == "art and entertainment":
                entertainment.append(df[i])
            elif category == "food and drink":
                food.append(df[i])
            elif category == "law, govt and politics":
                politics.append(df[i])
            elif category == "sports":
                sports.append(df[i])
    except:
        print (df[i])
        continue
# Out:
# been solved they finally picked up the second time i called thanks for the response jh   to dulles works
# need to work on your united flierfriendly program at the very least clue in your flight attendants
# space doctors notes and everything and on my first trip they lost my first suitcase among other issues not pleased with united
# s new flierfriendly is garbage just had to cry to get attendant to find a place for my medical supplies with limited overhead
# epic fail no jetway been here  mins on tarmac
# at the gate iad to rdu
# thanks for the link now finally arrived in brussels  h after schedule
# to operated b er from newark to zurich airport replacing b er between may sep instead till oct avgeek
# nd flight in two weeks that you have lost my bag taking my k status to neveragain worstcustomerservice
# hi what is the phone number for reservations in venezuela thanks
# can i request a ticket change through twitter
# ua flight was a nightmare from poor customer service having my confirmed seat given away more issues
# to start daily b er flights from newark to milan malpensa replacing b er on apr instead mar avgeek
# to start daily b er flights from newark to frankfurt fra replacing b er on jul avgeek
# has the best customer experience via twitter huge fan
# thank you for your response
# flight  last night was badbusiness will be a long time before i recommend united to anyone
# beyond frustrated sked change no seats earlier departure and double layover of course only seats are cust svc no help
# working with lisa j at ord she s working hard for us but this is still very disappointing was on  to ewr
# love the new st class breakfast
# i emailed the customer care via the website form after a long wait rachelle resolved my issue but i m still irritated w united
# flight cancelled flightled and the updated one gets me into bwi too late flight i d be fine with dca or iad just arriving earlier help
# so is the jj standing for just joking i am not finding the humor
#   sfo dfw also  sfo ord
# omg omg omg i just did
# de icing is important
# process begins
# i love jet blue
# i feel sorry for aa
#   doesn t help me

# %%
pd.DataFrame(entertainment).to_csv("entertainment.csv", header = ['text'])
pd.DataFrame(food).to_csv("food.csv", header = ['text'])
pd.DataFrame(politics).to_csv("politics.csv", header = ['text'])
pd.DataFrame(sports).to_csv("sports.csv", header = ['text'])
pd.DataFrame(health).to_csv("health.csv", header = ['text'])

# %% [markdown]
# ## Get Popular Topics

# %%
#load Wiki-trained LDA model

base = "/Users/prachi.agrawal/Desktop/Fall2018Courses/599Project/wiki/"
from gensim.test.utils import datapath
from gensim import corpora, models
model_name = datapath(base+"model/test")
lda = models.ldamulticore.LdaMulticore.load(model_name)

# %%
# load dictionary and corpus from the wiki-trianed model

import gensim
base_md = "/Users/prachi.agrawal/Desktop/Fall2018Courses/599Project/wiki/m_vecs/"
dictionary = gensim.corpora.Dictionary.load_from_text(base_md+'_wordids.txt')
corpus = gensim.corpora.MmCorpus(base_md+'_tfidf.mm')

# %%
# print topics (1000) from LDA

for idx, topic in lda.print_topics(-1):
    print('Topic Number: {}\t \nWord Distribution: {}'.format(idx, topic))
# Out:
# Topic Number: 0
# Topic Number: 13
# Word Distribution: 0.021*"shoe" + 0.018*"shoes" + 0.014*"boots" + 0.014*"harvey" + 0.012*"durham" + 0.011*"footwear" + 0.011*"boot" + 0.010*"fetish" + 0.006*"langley" + 0.006*"heel"
# Topic Number: 14
# Word Distribution: 0.054*"flight" + 0.031*"aircraft" + 0.027*"crash" + 0.023*"plane" + 0.021*"faa" + 0.020*"robin" + 0.019*"taxi" + 0.019*"aviation" + 0.019*"hood" + 0.018*"cargo"
# Topic Number: 15
# Word Distribution: 0.069*"zappa" + 0.065*"prostitution" + 0.044*"dickens" + 0.042*"prostitutes" + 0.031*"louie" + 0.020*"wives" + 0.018*"cern" + 0.018*"bowery" + 0.016*"husbands" + 0.015*"stroud"
# Topic Number: 16
# Word Distribution: 0.012*"mussolini" + 0.011*"fascist" + 0.009*"belarusian" + 0.009*"italian" + 0.007*"zorro" + 0.007*"nye" + 0.007*"fascism" + 0.006*"drilling" + 0.005*"benito" + 0.005*"fd"
# Topic Number: 17
# Word Distribution: 0.033*"pin" + 0.030*"connector" + 0.029*"pins" + 0.028*"bits" + 0.027*"connectors" + 0.018*"bit" + 0.015*"nat" + 0.013*"encoder" + 0.012*"adc" + 0.011*"shooters"
# Topic Number: 18
# Word Distribution: 0.003*"monster" + 0.003*"plot" + 0.003*"creature" + 0.003*"novel" + 0.002*"movie" + 0.002*"characters" + 0.002*"kill" + 0.002*"episode" + 0.002*"finds" + 0.002*"woman"
# Topic Number: 19
# Word Distribution: 0.077*"prison" + 0.058*"prisoners" + 0.043*"inmates" + 0.021*"execution" + 0.020*"prisons" + 0.019*"inmate" + 0.017*"correctional" + 0.014*"camp" + 0.012*"penitentiary" + 0.011*"kai"
# Topic Number: 20
# Word Distribution: 0.035*"flint" + 0.035*"blackhawks" + 0.030*"linda" + 0.022*"terminator" + 0.021*"jg" + 0.018*"gulfstream" + 0.018*"stowe" + 0.017*"mustangs" + 0.017*"brandy" + 0.015*"beecher"
# Topic Number: 21
# Word Distribution: 0.056*"canada" + 0.051*"canadian" + 0.029*"ontario" + 0.017*"toronto" + 0.017*"nova" + 0.015*"vancouver" + 0.013*"scotia" + 0.012*"newfoundland" + 0.012*"canadians" + 0.012*"manitoba"
# Topic Number: 22
# Word Distribution: 0.018*"newspaper" + 0.018*"editor" + 0.014*"magazine" + 0.013*"news" + 0.012*"paper" + 0.012*"journalism" + 0.010*"newspapers" + 0.010*"daily" + 0.010*"editorial" + 0.007*"press"
# Topic Number: 23
# Word Distribution: 0.013*"billion" + 0.013*"acquired" + 0.012*"corporation" + 0.011*"shareholders" + 0.010*"subsidiary" + 0.010*"holdings" + 0.009*"corp" + 0.009*"stake" + 0.009*"inc" + 0.008*"ltd"
# Topic Number: 24
# Word Distribution: 0.067*"mcguire" + 0.052*"facebook" + 0.049*"tn" + 0.047*"sushi" + 0.039*"cuomo" + 0.037*"connors" + 0.036*"mathias" + 0.033*"pellets" + 0.025*"prashant" + 0.025*"zuckerberg"
# Topic Number: 25
# Word Distribution: 0.011*"gender" + 0.011*"sexual" + 0.009*"sex" + 0.006*"feminist" + 0.006*"male" + 0.006*"female" + 0.005*"child" + 0.004*"sexuality" + 0.004*"feminism" + 0.003*"woman"
# Topic Number: 26
# Word Distribution: 0.026*"aba" + 0.014*"grading" + 0.011*"trooper" + 0.011*"paracetamol" + 0.010*"pubic" + 0.009*"dic" + 0.009*"bok" + 0.008*"weisman" + 0.008*"yell" + 0.008*"communicator"
# Topic Number: 27
# Word Distribution: 0.022*"titanic" + 0.020*"pavilion" + 0.011*"rms" + 0.010*"riga" + 0.009*"lifeboat" + 0.008*"berne" + 0.008*"sinking" + 0.008*"bloomsbury" + 0.007*"couch" + 0.007*"pavilions"
# Topic Number: 28
# Word Distribution: 0.094*"trilogy" + 0.087*"ashley" + 0.051*"eleanor" + 0.046*"teller" + 0.041*"atalanta" + 0.040*"susie" + 0.030*"arbor" + 0.027*"tetralogy" + 0.027*"incubator" + 0.027*"involuntary"
# Topic Number: 29
# Word Distribution: 0.129*"lake" + 0.038*"fairy" + 0.023*"trout" + 0.023*"lakes" + 0.018*"grimm" + 0.018*"ginger" + 0.018*"spindle" + 0.017*"fairies" + 0.017*"carp" + 0.014*"bradbury"
# Topic Number: 30
# Word Distribution: 0.039*"species" + 0.012*"genus" + 0.007*"eggs" + 0.007*"animals" + 0.007*"prey" + 0.005*"insects" + 0.005*"taxonomy" + 0.005*"habitat" + 0.004*"tail" + 0.004*"food"
# Topic Number: 31
# Word Distribution: 0.257*"swedish" + 0.180*"sweden" + 0.104*"stockholm" + 0.048*"om" + 0.034*"jag" + 0.031*"erik" + 0.030*"lars" + 0.022*"swedes" + 0.020*"sveriges" + 0.019*"och"
# Topic Number: 32
# Word Distribution: 0.028*"earthquake" + 0.018*"pharmaceutical" + 0.015*"fda" + 0.014*"earthquakes" + 0.013*"pharmaceuticals" + 0.011*"quake" + 0.011*"drug" + 0.010*"nasal" + 0.010*"seismic" + 0.010*"fault"
# Topic Number: 33
# Word Distribution: 0.020*"helmet" + 0.011*"michelin" + 0.009*"boyer" + 0.009*"helmets" + 0.008*"maverick" + 0.007*"frampton" + 0.007*"hunan" + 0.007*"iaf" + 0.007*"dassault" + 0.007*"bateman"
# Topic Number: 34
# Word Distribution: 0.014*"augustine" + 0.014*"ezra" + 0.014*"jerome" + 0.013*"wilcox" + 0.012*"billings" + 0.011*"robbie" + 0.011*"hairstyle" + 0.011*"bibles" + 0.010*"hippo" + 0.010*"codex"
# Topic Number: 35
# Word Distribution: 0.010*"rothschild" + 0.008*"higgins" + 0.007*"pawn" + 0.007*"stirling" + 0.005*"fonda" + 0.005*"chess" + 0.005*"beatty" + 0.004*"ub" + 0.004*"startups" + 0.004*"puppetry"
# Topic Number: 36
# Word Distribution: 0.015*"audio" + 0.014*"unix" + 0.013*"php" + 0.010*"perl" + 0.009*"ic" + 0.009*"transistor" + 0.009*"bytes" + 0.009*"byte" + 0.008*"midi" + 0.008*"logic"
# Topic Number: 37
# Word Distribution: 0.013*"mcbride" + 0.013*"babylonian" + 0.012*"assyrian" + 0.010*"berlusconi" + 0.009*"cuneiform" + 0.009*"scunthorpe" + 0.009*"mesopotamian" + 0.009*"sumerian" + 0.009*"steinberg" + 0.008*"bc"
# Topic Number: 62
# Word Distribution: 0.153*"rational" + 0.135*"workpiece" + 0.088*"irrational" + 0.059*"rationality" + 0.024*"workpieces" + 0.023*"quench" + 0.002*"spindles" + 0.000*"nitride" + 0.000*"rationally" + 0.000*"porosity"
# Topic Number: 63
# Word Distribution: 0.025*"vision" + 0.022*"retina" + 0.022*"retinal" + 0.020*"visual" + 0.019*"eye" + 0.014*"petty" + 0.014*"blindness" + 0.012*"optic" + 0.012*"hari" + 0.010*"pryor"
# Topic Number: 64
# Word Distribution: 0.057*"golf" + 0.039*"pga" + 0.034*"tour" + 0.022*"woods" + 0.017*"hole" + 0.017*"golfer" + 0.015*"tee" + 0.013*"championship" + 0.012*"baird" + 0.012*"par"
# Topic Number: 65
# Word Distribution: 0.032*"jesus" + 0.017*"christ" + 0.013*"gospel" + 0.010*"christian" + 0.010*"church" + 0.009*"holy" + 0.008*"testament" + 0.007*"god" + 0.007*"mary" + 0.007*"christians"
# Topic Number: 66
# Word Distribution: 0.092*"jones" + 0.084*"animation" + 0.058*"animated" + 0.049*"cartoon" + 0.038*"dexter" + 0.036*"hanna" + 0.024*"animator" + 0.024*"barbera" + 0.018*"tammy" + 0.017*"abrams"
# Topic Number: 67
# Word Distribution: 0.012*"dna" + 0.009*"clade" + 0.009*"mitochondrial" + 0.009*"sequencing" + 0.008*"gibbs" + 0.008*"membrane" + 0.007*"taxa" + 0.007*"miocene" + 0.007*"atp" + 0.006*"lineages"
# Topic Number: 68
# Word Distribution: 0.039*"lyon" + 0.038*"nes" + 0.020*"famicom" + 0.017*"icon" + 0.017*"kun" + 0.016*"ransom" + 0.014*"groupe" + 0.013*"knuckles" + 0.011*"monogatari" + 0.011*"akash"
# Topic Number: 69
# Word Distribution: 0.019*"ivan" + 0.018*"robotics" + 0.013*"tolstoy" + 0.011*"petersburg" + 0.011*"origami" + 0.011*"beggar" + 0.010*"robotic" + 0.010*"aiken" + 0.010*"logarithm" + 0.009*"actuator"
# Topic Number: 70
# Word Distribution: 0.012*"dish" + 0.012*"food" + 0.012*"cuisine" + 0.011*"meat" + 0.009*"sauce" + 0.009*"rice" + 0.008*"chicken" + 0.008*"dishes" + 0.008*"bread" + 0.008*"ingredients"
# Topic Number: 71
# Word Distribution: 0.010*"sound" + 0.009*"bon" + 0.007*"acoustic" + 0.006*"electric" + 0.004*"jovi" + 0.004*"electrical" + 0.004*"audio" + 0.004*"wires" + 0.004*"microphone" + 0.004*"faraday"
# Topic Number: 72
# Word Distribution: 0.047*"bet" + 0.031*"alexandra" + 0.028*"betting" + 0.025*"willie" + 0.021*"csf" + 0.018*"winnings" + 0.017*"icp" + 0.017*"bets" + 0.014*"pta" + 0.014*"odds"
# Topic Number: 73
# Topic Number: 98
# Word Distribution: 0.042*"cave" + 0.013*"dhaka" + 0.013*"gonzalez" + 0.012*"narnia" + 0.011*"lavender" + 0.011*"cbbc" + 0.011*"grandma" + 0.011*"chittagong" + 0.010*"hoya" + 0.010*"sponge"
# Topic Number: 99
# Word Distribution: 0.030*"atlético" + 0.026*"copa" + 0.025*"kbit" + 0.023*"américa" + 0.022*"libertadores" + 0.021*"pd" + 0.021*"série" + 0.021*"blanco" + 0.020*"xm" + 0.019*"bari"
# Topic Number: 100
# Word Distribution: 0.055*"puerto" + 0.034*"rico" + 0.030*"sm" + 0.021*"rican" + 0.016*"teddy" + 0.010*"spanish" + 0.010*"muñoz" + 0.010*"del" + 0.009*"lipstick" + 0.008*"el"
# Topic Number: 101
# Word Distribution: 0.049*"sri" + 0.037*"lanka" + 0.016*"lankan" + 0.014*"india" + 0.012*"colombo" + 0.010*"tamil" + 0.009*"ceylon" + 0.009*"indian" + 0.009*"caste" + 0.007*"sikhs"
# Topic Number: 102
# Word Distribution: 0.004*"sociology" + 0.003*"society" + 0.003*"philosophy" + 0.003*"theory" + 0.003*"science" + 0.002*"cultural" + 0.002*"professor" + 0.002*"essay" + 0.002*"literary" + 0.002*"ideas"
# Topic Number: 103
# Word Distribution: 0.020*"quinn" + 0.019*"sam" + 0.014*"housewives" + 0.012*"glee" + 0.011*"bruno" + 0.009*"jessica" + 0.008*"moreno" + 0.008*"selena" + 0.007*"desperate" + 0.007*"maid"
# Topic Number: 104
# Word Distribution: 0.042*"diabetes" + 0.041*"glucose" + 0.034*"insulin" + 0.023*"obesity" + 0.019*"pancreas" + 0.015*"pancreatic" + 0.014*"diet" + 0.013*"diabetic" + 0.013*"steroid" + 0.012*"hla"
# Topic Number: 105
# Word Distribution: 0.040*"couture" + 0.038*"designer" + 0.028*"fashion" + 0.027*"elle" + 0.026*"boutique" + 0.021*"ronan" + 0.021*"guetta" + 0.021*"tennant" + 0.018*"sportswear" + 0.017*"saks"
# Topic Number: 106
# Word Distribution: 0.120*"volleyball" + 0.057*"maher" + 0.047*"biddle" + 0.037*"pundit" + 0.035*"bounds" + 0.034*"aviator" + 0.031*"habermas" + 0.029*"derogatory" + 0.028*"pandit" + 0.022*"jürgen"
# Topic Number: 107
# Word Distribution: 0.023*"apple" + 0.022*"disk" + 0.019*"mac" + 0.014*"macintosh" + 0.012*"rom" + 0.011*"drives" + 0.011*"mb" + 0.010*"disks" + 0.009*"drive" + 0.009*"firmware"
# Topic Number: 108
# Word Distribution: 0.016*"carbon" + 0.011*"reaction" + 0.009*"acid" + 0.008*"compounds" + 0.007*"organic" + 0.007*"oxygen" + 0.007*"synthesis" + 0.006*"chemical" + 0.006*"dioxide" + 0.006*"reactions"
# Topic Number: 109
# Word Distribution: 0.016*"schumacher" + 0.015*"brunei" + 0.013*"karan" + 0.009*"ibiza" + 0.006*"rubens" + 0.006*"catwalk" + 0.006*"coogan" + 0.005*"cosworth" + 0.004*"vesicle" + 0.004*"stratum"
# Topic Number: 110
# Word Distribution: 0.018*"hacker" + 0.015*"hack" + 0.015*"igbo" + 0.013*"pascal" + 0.011*"peggy" + 0.010*"hackers" + 0.009*"cary" + 0.009*"oats" + 0.008*"hacks" + 0.008*"norfolk"
# Topic Number: 123
# Word Distribution: 0.041*"indonesia" + 0.033*"indonesian" + 0.022*"jakarta" + 0.010*"simulator" + 0.009*"java" + 0.009*"sultan" + 0.007*"turkish" + 0.007*"bali" + 0.006*"hostess" + 0.005*"cz"
# Topic Number: 124
# Word Distribution: 0.040*"kannada" + 0.031*"karnataka" + 0.024*"peugeot" + 0.021*"emma" + 0.020*"citroën" + 0.016*"kia" + 0.015*"akademi" + 0.015*"sahitya" + 0.013*"psa" + 0.012*"peel"
# Topic Number: 125
# Word Distribution: 0.029*"instrument" + 0.029*"eurovision" + 0.027*"contest" + 0.022*"instruments" + 0.021*"strings" + 0.021*"string" + 0.013*"tuning" + 0.012*"burns" + 0.009*"atkins" + 0.008*"haynes"
# Topic Number: 126
# Word Distribution: 0.064*"kenya" + 0.035*"detroit" + 0.026*"michigan" + 0.025*"kenyan" + 0.023*"nairobi" + 0.013*"csa" + 0.009*"county" + 0.008*"eads" + 0.008*"emitter" + 0.008*"turkana"
# Topic Number: 127
# Word Distribution: 0.025*"sf" + 0.016*"benn" + 0.015*"magdalena" + 0.014*"pollard" + 0.012*"macross" + 0.012*"gannett" + 0.012*"cpl" + 0.012*"ola" + 0.010*"jie" + 0.010*"mor"
# Topic Number: 128
# Word Distribution: 0.027*"talbot" + 0.027*"transform" + 0.025*"fourier" + 0.023*"frost" + 0.019*"galactica" + 0.019*"ballard" + 0.016*"laplace" + 0.015*"battlestar" + 0.013*"gardiner" + 0.013*"fullerton"
# Topic Number: 129
# Word Distribution: 0.024*"defendant" + 0.017*"plaintiff" + 0.015*"damages" + 0.014*"liability" + 0.013*"mazda" + 0.012*"tort" + 0.010*"lamborghini" + 0.010*"baku" + 0.010*"negligence" + 0.009*"breach"
# Topic Number: 130
# Word Distribution: 0.035*"punk" + 0.020*"bands" + 0.016*"hardcore" + 0.015*"rock" + 0.014*"sound" + 0.013*"band" + 0.010*"genre" + 0.010*"synthesizer" + 0.009*"metal" + 0.009*"sounds"
# Topic Number: 131
# Word Distribution: 0.006*"su" + 0.005*"strap" + 0.005*"jar" + 0.005*"smiley" + 0.004*"heap" + 0.004*"asher" + 0.004*"straps" + 0.004*"nylon" + 0.003*"sukhoi" + 0.003*"braxton"
# Topic Number: 132
# Word Distribution: 0.059*"dance" + 0.020*"dancing" + 0.019*"ballet" + 0.017*"dancer" + 0.017*"dancers" + 0.016*"dances" + 0.008*"danced" + 0.007*"choreography" + 0.006*"choreographed" + 0.006*"naughty"
# Topic Number: 133
# Word Distribution: 0.069*"album" + 0.050*"chart" + 0.036*"singles" + 0.036*"billboard" + 0.026*"albums" + 0.020*"peaked" + 0.019*"hot" + 0.015*"studio" + 0.015*"discography" + 0.014*"uk"
# Topic Number: 134
# Word Distribution: 0.044*"burnett" + 0.030*"lucky" + 0.028*"acm" + 0.028*"waits" + 0.024*"luck" + 0.022*"krauss" + 0.021*"hobart" + 0.020*"fearless" + 0.019*"nellie" + 0.019*"mts"
# Topic Number: 135
# Word Distribution: 0.059*"jazz" + 0.052*"mitchell" + 0.030*"kenny" + 0.027*"chambers" + 0.025*"panda" + 0.025*"gillespie" + 0.023*"hubbard" + 0.022*"byrd" + 0.021*"coltrane" + 0.021*"cp"
# Topic Number: 136
# Word Distribution: 0.049*"coffee" + 0.034*"beach" + 0.030*"robot" + 0.023*"robots" + 0.009*"boardwalk" + 0.009*"hopper" + 0.009*"bot" + 0.009*"rourke" + 0.008*"seaside" + 0.008*"conor"
# Topic Number: 137
# Word Distribution: 0.037*"cornell" + 0.036*"lowe" + 0.017*"fay" + 0.017*"seeker" + 0.016*"boa" + 0.015*"pinto" + 0.012*"keeler" + 0.012*"amon" + 0.012*"ziegfeld" + 0.012*"imo"
# Topic Number: 138
# Word Distribution: 0.013*"tolkien" + 0.009*"sensors" + 0.009*"iodine" + 0.007*"sensor" + 0.007*"detector" + 0.007*"iodide" + 0.006*"alarm" + 0.006*"detectors" + 0.006*"map" + 0.006*"selenium"
# Topic Number: 139
# Word Distribution: 0.062*"congo" + 0.022*"congolese" + 0.021*"lear" + 0.020*"burkina" + 0.020*"cameroon" + 0.019*"faso" + 0.018*"penelope" + 0.016*"gabon" + 0.016*"othello" + 0.015*"den"
# Topic Number: 140
# Word Distribution: 0.224*"cuban" + 0.209*"cuba" + 0.103*"castro" + 0.093*"havana" + 0.056*"garcía" + 0.044*"miami" + 0.039*"fidel" + 0.031*"cubans" + 0.005*"evaristo" + 0.004*"garcia"
# Topic Number: 141
# Word Distribution: 0.032*"mia" + 0.031*"soda" + 0.025*"matrix" + 0.021*"row" + 0.021*"watts" + 0.019*"ras" + 0.019*"iterative" + 0.017*"iteration" + 0.016*"telegraph" + 0.015*"chicano"
# Topic Number: 142
# Word Distribution: 0.037*"rotor" + 0.028*"helicopter" + 0.014*"ap" + 0.014*"helicopters" + 0.011*"sikorsky" + 0.011*"microscope" + 0.010*"imaging" + 0.010*"microscopy" + 0.010*"scanning" + 0.009*"rotors"
# Topic Number: 143
# Word Distribution: 0.052*"argentina" + 0.047*"argentine" + 0.036*"aires" + 0.036*"buenos" + 0.016*"benson" + 0.011*"quentin" + 0.011*"plata" + 0.009*"córdoba" + 0.009*"tarantino" + 0.008*"la"
# Topic Number: 144
# Word Distribution: 0.093*"fox" + 0.040*"cw" + 0.025*"wb" + 0.020*"scully" + 0.020*"channel" + 0.020*"upn" + 0.020*"taft" + 0.019*"mulder" + 0.018*"tin" + 0.018*"paramount"
# Topic Number: 145
# Word Distribution: 0.044*"river" + 0.014*"rivers" + 0.014*"dam" + 0.011*"lake" + 0.011*"basin" + 0.011*"flood" + 0.010*"flows" + 0.008*"sea" + 0.008*"flow" + 0.007*"lakes"
# Topic Number: 146
# Word Distribution: 0.054*"playboy" + 0.028*"sims" + 0.021*"sid" + 0.019*"kiss" + 0.019*"davenport" + 0.017*"malibu" + 0.016*"weir" + 0.016*"ndp" + 0.014*"crüe" + 0.014*"steyr"
# Word Distribution: 0.020*"coleman" + 0.016*"walton" + 0.013*"crimson" + 0.012*"randall" + 0.008*"prepaid" + 0.007*"flagg" + 0.007*"caesars" + 0.007*"masks" + 0.005*"umberto" + 0.005*"stinson"
# Topic Number: 989
# Word Distribution: 0.041*"graham" + 0.023*"gill" + 0.020*"lola" + 0.014*"ide" + 0.013*"vm" + 0.009*"wiseman" + 0.008*"dislocation" + 0.008*"zooplankton" + 0.007*"cheerleaders" + 0.007*"cheer"
# Topic Number: 990
# Word Distribution: 0.058*"police" + 0.024*"officers" + 0.020*"enforcement" + 0.015*"department" + 0.013*"patrol" + 0.011*"officer" + 0.011*"agencies" + 0.011*"security" + 0.010*"agency" + 0.008*"bureau"
# Topic Number: 991
# Word Distribution: 0.059*"code" + 0.036*"codes" + 0.032*"telephone" + 0.027*"mobile" + 0.023*"digit" + 0.020*"phone" + 0.016*"digits" + 0.015*"numbers" + 0.014*"phones" + 0.014*"call"
# Topic Number: 992
# Word Distribution: 0.270*"jay" + 0.075*"cuny" + 0.054*"oas" + 0.051*"remedial" + 0.036*"yongle" + 0.011*"doctrina" + 0.000*"intercultural" + 0.000*"christiana" + 0.000*"adjunct" + 0.000*"library"
# Topic Number: 993
# Word Distribution: 0.130*"roberts" + 0.114*"oklahoma" + 0.090*"classification" + 0.054*"hoax" + 0.034*"cottage" + 0.033*"classifications" + 0.028*"handbook" + 0.027*"adoption" + 0.027*"ponies" + 0.026*"adoptive"
# Topic Number: 994
# Word Distribution: 0.039*"blair" + 0.019*"bodybuilder" + 0.013*"felicity" + 0.013*"cade" + 0.012*"lucie" + 0.012*"mobil" + 0.012*"paltrow" + 0.010*"plaques" + 0.010*"blank" + 0.010*"gwyneth"
# Topic Number: 995
# Word Distribution: 0.027*"pharmacy" + 0.021*"jacksonville" + 0.019*"jaguars" + 0.019*"slovenian" + 0.017*"slovenia" + 0.015*"senegal" + 0.013*"slovene" + 0.012*"howard" + 0.012*"communes" + 0.011*"dakar"
# Topic Number: 996
# Word Distribution: 0.071*"pie" + 0.045*"coco" + 0.042*"judith" + 0.039*"adidas" + 0.031*"yeah" + 0.030*"rocha" + 0.030*"pivot" + 0.029*"kip" + 0.026*"spike" + 0.022*"supermodel"
# Topic Number: 997
# Word Distribution: 0.035*"roth" + 0.023*"shields" + 0.022*"annie" + 0.021*"connor" + 0.019*"vaughn" + 0.016*"teal" + 0.013*"tod" + 0.012*"haas" + 0.012*"cecilia" + 0.012*"wick"
# Topic Number: 998
# Word Distribution: 0.016*"software" + 0.011*"windows" + 0.010*"user" + 0.009*"data" + 0.009*"file" + 0.008*"server" + 0.008*"microsoft" + 0.007*"users" + 0.007*"linux" + 0.006*"files"
# Topic Number: 999
# Word Distribution: 0.000*"gneisses" + 0.000*"hilaire" + 0.000*"augite" + 0.000*"facies" + 0.000*"glassy" + 0.000*"spats" + 0.000*"nepheline" + 0.000*"monoclinic" + 0.000*"satirising" + 0.000*"mohs"

# %%
test_files = ["health.csv", "entertainment.csv", "food.csv", "politics.csv", "sports.csv"]

# for file in test_files:
df = pd.read_csv("health.csv", index_col = None)
test_df = df['text']
words_corpus_test = []

for i in range(0,len(test_df)):
    words_corpus_test.append([word for word in test_df[i].lower().split() if len(word)>3])

print(words_corpus_test)
# Out:
# [['know', 'that', 'suicide', 'second', 'leading', 'cause', 'death', 'among', 'teens'], ['down', 'with', 'yeah', 'know'], ['book', 'seats', 'your', 'flights', 'when', 'them', 'even', 'during', 'check', 'creates', 'much', 'anxiety', 'frustrated'], ['requested', 'window', 'seat', 'confirmed', 'window', 'stuck', 'middle', 'seat', 'good', 'treat', 'silver', 'member'], ['help', 'this', 'fund', 'needs', 'urgent', 'treatment', 'battling', 'cancer', 'could', 'help', 'with', 'flights', 'freyasfund'], ['digging', 'swanky', 'pink', 'mood', 'lighting', 'during', 'flight', 'from', 'just', 'needs', 'cabaret', 'singer', 'think', 'about'], ['help', 'with', 'flights', 'battling', 'cancer', 'needs', 'treatment', 'fund'], ['wondering', 'guys', 'recieved', 'able', 'potentially', 'respond', 'asap'], ['once', 'found', 'problem', 'avoided', 'like', 'plague', 'told', 'find', 'supervisor'], ['ours', 'july', 'have', 'zero', 'excuses', 'this', 'have', 'date', 'system', 'that', 'causes', 'problems', 'like', 'this'], ['what', 'does', 'someone', 'with', 'severe', 'anxiety', 'when', 'person', 'help', 'next'], ['nope', 'they', 'told', 'time', 'them', 'home', 'sleep', 'airport', 'even', 'though', 'they', 'assured', 'would', 'room'], ['deep', 'vein', 'thrombosis'], ['constantly', 'having', 'challenges', 'with', 'upgrades', 'charges', 'order', 'prevent', 'have', 'addtl'], ['encouraged', 'that', 'have', 'cpap', 'tonight'], ['soooo', 'been', 'days', 'offered', 'response', 'assume', 'poor', 'treatment', 'gate', 'agents', 'norm'], ['response', 'back'], ['worst', 'will', 'avoid', 'like', 'plague'], ['shame', 'choosing', 'united', 'difference', 'between', 'reuniting', 'with', 'aging', 'friends', 'never', 'seeing', 'them', 'again', 'poorservice'], [], ['freq', 'flyer', 'makes', 'cust', 'needing', 'assistance', 'treated', 'poorly', 'servicefail'], ['cancelled', 'flightled', 'flight', 'cause', 'crew', 'needed', 'sleep', 'totally', 'okay', 'wake', 'just', 'know', 'cancelled', 'flightled', 'again'], ['denver', 'baggage', 'handlers', 'totally', 'impressed', 'today', 'lungs', 'barely', 'made', 'connect', 'bags', 'problem'], ['thanks', 'this', 'occur', 'guys', 'hours', 'extra', 'your', 'delay', 'that', 'hours', 'fail'], ['finally', 'through', 'they', 'were', 'very', 'helpful', 'appreciate'], ['flight', 'delayed', 'hours', 'lost', 'wallet', 'have', 'money', 'sleep', 'your', 'representatives', 'will', 'help', 'unitedsucks'], ['would', 'understand', 'weather', 'issue', 'airline', 'maintenance', 'sleep', 'airport', 'floor', 'lose', 'entire'], ['weight', 'restriction', 'many', 'this', 'plane'], ['guess', 'what', 'doing', 'sleeping', 'cause', 'care', 'little', 'about', 'your', 'customers', 'them', 'sleep', 'airports'], ['sharing', 'alright', 'especially', 'about', 'sleeping', 'this', 'shitty', 'airport', 'getting', 'sleep', 'night', 'because'], ['disgusting', 'unconscionable', 'treatment', 'received', 'tonight'], ['look', 'people', 'tryn', 'sleep', 'airport', 'your', 'shitty', 'company', 'comping', 'rooms', 'after', 'flight'], ['spoke', 'with', 'baggage', 'contact', 'number', 'said', 'they', 'will', 'bags', 'stay', 'pick', 'tmrw'], ['made', 'unplanned', 'landing', 'because', 'pressurization', 'failure', 'worst', 'pain', 'ever', 'felt', 'thought', 'going', 'pass'], ['could', 'really', 'your', 'help', 'getting', 'bags', 'headed', 'going'], ['saturday', 'this', 'morning', 'dies', 'from', 'ebola'], ['left', 'gate', 'minutes', 'early', 'thoughts', 'that', 'doesn', 'count', 'tarmac', 'half', 'hour', 'comeonpeople'], ['guys', 'made', 'treated', 'well', 'thank'], ['that', 'think', 'important', 'resolve', 'your', 'client', 'facing', 'team', 'that', 'behaves', 'disgraceful'], ['patient', 'without', 'offering', 'something', 'return'], ['uhuh', 'group', 'trying', 'nashville', 'into', 'today', 'instead', 'tomorrow', 'preemptive', 'though'], ['thank', 'appreciate', 'response'], ['flight', 'awful', 'only', 'lavatory', 'functioning', 'people', 'lining', 'bumping', 'because', 'class', 'bathroom', ' ...

# %%
corpus_bow = [dictionary.doc2bow(text) for text in words_corpus_test]

# %%
freq_dict = dict()
for i in range(0, len(corpus_bow)):
    print(i)
    count = 0
    for index, score in sorted(lda[corpus_bow[i]], key=lambda tup: -1*tup[1]):
        if index in freq_dict:
            freq_dict[index] += 1
        else:
            freq_dict[index] = 1
        print("\nScore: {}\t \nTopic Number: {}\t \nWord Distribution: {}".format(score, index, lda.print_topic(index, 10)))
        break
    print("\n\n\n")
# Out:
# 0
#
# Score: 0.47467878460884094
# Topic Number: 18
# Word Distribution: 0.003*"monster" + 0.003*"plot" + 0.003*"creature" + 0.003*"novel" + 0.002*"movie" + 0.002*"characters" + 0.002*"kill" + 0.002*"episode" + 0.002*"finds" + 0.002*"woman"
#
#
#
#
# 1
#
# Score: 0.2217264324426651
# Topic Number: 527
# Word Distribution: 0.163*"airport" + 0.046*"terminal" + 0.034*"airlines" + 0.033*"flights" + 0.029*"runway" + 0.026*"airports" + 0.026*"passengers" + 0.026*"destinations" + 0.024*"aviation" + 0.023*"aircraft"
#
#
#
#
# 2
#
# Score: 0.28327518701553345
# Topic Number: 441
# Word Distribution: 0.028*"network" + 0.025*"cable" + 0.022*"wireless" + 0.021*"networks" + 0.019*"internet" + 0.014*"broadband" + 0.013*"communications" + 0.013*"ethernet" + 0.012*"ieee" + 0.012*"telecom"
#
#
#
#
# 3
#
# Score: 0.2502500116825104
# Topic Number: 134
# Word Distribution: 0.044*"burnett" + 0.030*"lucky" + 0.028*"acm" + 0.028*"waits" + 0.024*"luck" + 0.022*"krauss" + 0.021*"hobart" + 0.020*"fearless" + 0.019*"nellie" + 0.019*"mts"
#
#
#
#
# 4
#
# Score: 0.24161402881145477
# Topic Number: 277
# Word Distribution: 0.011*"vehicle" + 0.009*"cars" + 0.008*"wheel" + 0.007*"tire" + 0.007*"automotive" + 0.006*"vehicles" + 0.006*"hydraulic" + 0.006*"weight" + 0.006*"fitted" + 0.005*"auto"
#
#
#
#
# 5
#
# Score: 0.2753446400165558
# Topic Number: 173
# Word Distribution: 0.042*"tree" + 0.034*"flowers" + 0.024*"leaves" + 0.023*"cm" + 0.023*"fruit" + 0.020*"trees" + 0.016*"flower" + 0.014*"bark" + 0.014*"cultivation" + 0.014*"species"
#
#
#
#
# 6
#
# Score: 0.2573842704296112
# Topic Number: 21
# Word Distribution: 0.056*"canada" + 0.051*"canadian" + 0.029*"ontario" + 0.017*"toronto" + 0.017*"nova" + 0.015*"vancouver" + 0.013*"scotia" + 0.012*"newfoundland" + 0.012*"canadians" + 0.012*"manitoba"
#
#
#
#
# 7
#
# Score: 0.3228842616081238
# Topic Number: 540
# Word Distribution: 0.047*"mills" + 0.024*"pigeon" + 0.016*"edith" + 0.015*"lexus" + 0.015*"seasoning" + 0.015*"shaker" + 0.014*"ptc" + 0.014*"pigeons" + 0.013*"cowan" + 0.013*"pancake"
#
#
#
#
# 8
#
# Score: 0.2502500116825104
# Topic Number: 14
# Word Distribution: 0.054*"flight" + 0.031*"aircraft" + 0.027*"crash" + 0.023*"plane" + 0.021*"faa" + 0.020*"robin" + 0.019*"taxi" + 0.019*"aviation" + 0.019*"hood" + 0.018*"cargo"
#
#
#
#
# 9
#
# Score: 0.3334999978542328
# Topic Number: 147
# Word Distribution: 0.022*"drink" + 0.018*"dong" + 0.017*"drinks" + 0.017*"beverage" + 0.017*"juice" + 0.016*"wood" + 0.015*"sugar" + 0.013*"sol" + 0.013*"flavors" + 0.013*"bios"
#
#
#
#
# 10
#
# Score: 0.25028666853904724
# Topic Number: 14
# Word Distribution: 0.054*"flight" + 0.031*"aircraft" + 0.027*"crash" + 0.023*"plane" + 0.021*"faa" + 0.020*"robin" + 0.019*"taxi" + 0.019*"aviation" + 0.019*"hood" + 0.018*"cargo"
#
#
#
#
# 11
#
# Score: 0.750249981880188
# Topic Number: 198
# Word Distribution: 0.004*"episode" + 0.003*"tells" + 0.002*"plot" + 0.002*"finds" + 0.002*"asks" + 0.002*"novel" + 0.002*"tries" + 0.002*"goes" + 0.002*"decides" + 0.002*"gets"
#
#
#
#
# 12
#
# Score: 0.28585749864578247
# Topic Number: 555
# Word Distribution: 0.020*"caffeine" + 0.018*"betty" + 0.014*"udinese" + 0.014*"nursery" + 0.013*"indicator" + 0.013*"florian" + 0.013*"louisa" + 0.012*"ssh" + 0.011*"indicators" + 0.010*"vagus"
#
#
#
#
# 13
#
# Score: 0.6669999957084656
# Topic Number: 674
# Word Distribution: 0.044*"highway" + 0.034*"route" + 0.028*"interstate" + 0.018*"alberta" + 0.014*"road" + 0.011*"calgary" + 0.011*"highways" + 0.009*"county" + 0.009*"exit" + 0.009*"edmonton"
#
#
#
#
# 14
#
# Score: 0.33366668224334717
# Topic Number: 469
# Word Distribution: 0.022*"cannabis" + 0.020*"elliott" + 0.015*"marijuana" + 0.015*"halo" + 0.009*"angie" + 0.009*"metres" + 0.008*"greenfield" + 0.008*"dope" + 0.008*"missy" + 0.007*"awesome"
#
#
#
#
# 15
#
# Score: 0.2069450169801712
# Topic Number: 440
# Word Distribution: 0.009*"quests" + 0.008*"compilers" + 0.007*"compiler" + 0.007*"ais" + 0.006*"mukesh" + 0.006*"fortran" + 0.006*"quest" + 0.005*"peking" + 0.005*"smoothing" + 0.005*"items"
#
#
#
#
# 16
#
# Score: 0.16684377193450928
# Topic Number: 904
# Word Distribution: 0.076*"cheese" + 0.041*"milk" + 0.027*"cow" + 0.026*"pasta" + 0.023*"marsh" + 0.020*"herman" + 0.019*"emilia" + 0.017*"dairy" + 0.017*"bosco" + 0.016*"cheeses"

# %%
for k, v in freq_dict.items():
    print("Topic:", k, " Freq:", v)
# Out:
# Topic: 18  Freq: 1
# Topic: 527  Freq: 1
# Topic: 441  Freq: 1
# Topic: 134  Freq: 1
# Topic: 277  Freq: 1
# Topic: 173  Freq: 1
# Topic: 21  Freq: 1
# Topic: 540  Freq: 1
# Topic: 14  Freq: 2
# Topic: 147  Freq: 1
# Topic: 198  Freq: 1
# Topic: 555  Freq: 1
# Topic: 674  Freq: 1
# Topic: 469  Freq: 1
# Topic: 440  Freq: 1
# Topic: 904  Freq: 1

# %%
sorted_x = sorted(freq_dict.items(), key=operator.itemgetter(1), reverse = True)

# %% [markdown]
# ## Final words and phrases

# %%
for i in range(0, 2):
    print("Topic Number: {}\t \nWord Distribution: {}".format(sorted_x[i][0], lda.print_topic(sorted_x[i][0], 10)))
    print("\n")
# Out:
# Topic Number: 14
# Word Distribution: 0.054*"flight" + 0.031*"aircraft" + 0.027*"crash" + 0.023*"plane" + 0.021*"faa" + 0.020*"robin" + 0.019*"taxi" + 0.019*"aviation" + 0.019*"hood" + 0.018*"cargo"
#
#
# Topic Number: 18
# Word Distribution: 0.003*"monster" + 0.003*"plot" + 0.003*"creature" + 0.003*"novel" + 0.002*"movie" + 0.002*"characters" + 0.002*"kill" + 0.002*"episode" + 0.002*"finds" + 0.002*"woman"

# %% [markdown]
# ## Get Popular Entities and Corresponding sentiment

# %%
# Get Entities of each tweet 
# Get overall popular 5 entities with their sentiment

# %%
test_df.shape
# Out:
# (17,)

# %%
# Named Entity Recognition and Sentiment Analysis

nlp = en_core_web_sm.load()
analyser = SentimentIntensityAnalyzer()

frequent = dict()
for i in range(0,len(test_df)):
    tweet = test_df[i]
    tagged_sent = nltk.pos_tag([word for word in nltk.word_tokenize(tweet)])
    normalized_sent = [w.capitalize() if t in ["NN","NNS"] else w for (w,t) in tagged_sent]
    processed_tweet = ' '.join(normalized_sent)
    doc = nlp(processed_tweet)
    scores = analyser.polarity_scores(tweet)
    for X in doc.ents:
        if X.text in frequent:
            if X.label_ in ["PERSON", "ORG", "GPE"]:
                
                data = (frequent[X.text][0] + 1, frequent[X.text][1] + scores['pos'], frequent[X.text][2] + scores['neg'])
                frequent[X.text] = data
        
        else:
            if X.label_ in ["PERSON", "ORG", "GPE"]:
                frequent[X.text] = (1, scores['pos'], scores['neg'])
  
print(frequent)
#clustering : cluster Ranbir and Ranbir Singh together
# Out:
# {'Suicide': (6, 0.0, 2.472), 'Cause of Death': (6, 0.0, 2.472), 'Anxiety': (2, 0.192, 0.39), 'Seat': (3, 0.282, 0.583), 'Fund': (1, 0.291, 0.263), 'Battling Cancer': (2, 0.425, 0.585), 'Nyc': (2, 0.229, 0.169), 'Problem': (1, 0.106, 0.216), 'Plague': (2, 0.264, 0.615), 'Supervisor': (1, 0.106, 0.216), 'Time': (6, 0.557, 0.42800000000000005), 'Home': (1, 0.088, 0.0), 'Vein Thrombosis': (1, 0.0, 0.0), 'Challenges': (1, 0.127, 0.185), 'Upgrades amp Charges in Order': (1, 0.127, 0.185), 'Dvt': (1, 0.127, 0.185), 'Addtl': (1, 0.127, 0.185), 'Gate Agents': (1, 0.0, 0.227), 'Norm': (1, 0.0, 0.227), 'Difference': (2, 0.384, 0.124), 'Friends': (1, 0.236, 0.124), 'Baggage Handlers': (1, 0.077, 0.222), 'Lungs': (1, 0.077, 0.222), 'Occur': (1, 0.06, 0.236), 'Bag': (5, 0.182, 0.516), 'Delay': (2, 0.06, 0.33099999999999996), 'Appreciate': (1, 0.431, 0.0), 'Wallet': (1, 0.0, 0.337), 'Weather': (1, 0.0, 0.134), 'Airline Maintenance': (1, 0.0, 0.134), 'the Weight Restriction': (1, 0.0, 0.104), 'Cause': (3, 0.356, 0.268), 'Shitty Company': (1, 0.0, 0.153), 'Baggage Contact': (1, 0.053, 0.09), 'Iad for Pick': (1, 0.053, 0.09), 'Pain': (2, 0.16, 0.604), 'Iad': (3, 0.094, 0.0), 'Morning Man': (1, 0.0, 0.0), 'Doesn': (1, 0.0, 0.0), 'Tarmac': (2, 0.0, 0.2), 'Don': (2, 0.0, 0.0), 'Group': (1, 0.0, 0.0), 'Nashville': (1, 0.0, 0.0), 'Etc': (1, 0.0, 0.234), 'Class Bathroom': (1, 0.0, 0.234), 'Video Equipment': (1, 0.141, 0.237), 'Privilege': (1, 0.141, 0.237), 'Kit': (1, 0.153, 0.0), 'Practice': (1, 0.0, 0.412), 'Flight Passengers': (1, 0.0, 0.412), 'Pillows': (1, 0.0, 0.412), 'Lights': (1, 0.072, 0.088), 'Laguardia': (1, 0.0, 0.319), 'Nigeria': (1, 0.0, 0.319), 'Ou': (1, 0.0, 0.319), 'Iad for Ua': (1, 0.0, 0.22), 'Hrs': (2, 0.099, 0.297), 'Fail': (1, 0.0, 0.22), 'Headache': (1, 0.106, 0.066), 'Thru': (2, 0.106, 0.207), 'Ba Airways': (1, 0.321, 0.0), 'Plane Doesn': (1, 0.0, 0.0), 'Monopoly': (1, 0.263, 0.131), 'Crap': (2, 0.263, 0.525), 'Headaches': (2, 0.628, 0.0), 'Pls': (2, 0.159, 0.109), 'Plane': (6, 0.974, 0.377), 'Flt': (1, 0.099, 0.077), 'Lesson': (1, 0.252, 0.0), 'Rewards Points': (1, 0.286, 0.0), 'Account': (1, 0.286, 0.0), 'Southwestair Companion Pass': (1, 0.0, 0.0), 'Customer Service Rep Alex': (1, 0.163, 0.147), 'Booking Problems': (2, 0.33999999999999997, 0.40700000000000003), 'Insulin': (1, 0.0, 0.0), 'Hotel': (3, 0.21100000000000002, 0.242), 'St Louis': (1, 0.0, 0.227), 'Airpt': (1, 0.0, 0.227), 'Ahah': (1, 0.457, 0.0), 'Point': (2, 0.285, 0.096), 'York': (1, 0.131, 0.1), 'Reward Points': (1, 0.483, 0.091), 'Weight Loss': (1, 0.0, 0.103), 'Scale': (1, 0.0, 0.103), 'each Foot Home': (1, 0.0, 0.103), 'Process': (1, 0.307, 0.0), 'Gsp': (1, 0.0, 0.128), 'Avail': (1, 0.0, 0.128), 'Recap': (1, 0.273, 0.219), 'Guy': (1, 0.273, 0.219), 'Flight Vouchers': (1, 0.0, 0.185), 'Rebooks': (1, 0.225, 0.089), 'Sick': (1, 0.0, 0.623), 'Jfk': (1, 0.174, 0.0), 'Situation': (2, 0.309, 0.401), 'Lbs': (1, 0.0, 0.0), 'Carry': (1, 0.0, 0.0), 'Wifi on Flt': (1, 0.258, 0.099), 'Pbi': (1, 0.258, 0.099), 'Plane Don': (1, 0.0, 0.0), 'Cpap Machine': (1, 0.122, 0.0), 'Apnea': (1, 0.122, 0.0), 'no Info Thismosaicnothappy': (1, 0.0, 0.328), 'Place': (3, 0.0, 0.381), 'Baggage': (2, 0.199, 0.39), 'Trueblue': (1, 0.0, 0.129), 'Treat': (1, 0.474, 0.0), 'Stop at Jfk before Iad': (1, 0.0, 0.306), 'Allergies': (1, 0.058, 0.0), 'Bottle': (1, 0.058, 0.0), 'Benadryl': (1, 0.058, 0.0), 's Sch': (1, 0.174, 0.0), 'Aa': (10, 1.396, 1.3400000000000003), 'Yall': (1, 0.174, 0.0), 'Fll': (1, 0.174, 0.0), 'Freezing': (1, 0.229, 0.169), 'Lounge': (1, 0.427, 0.0), 'Air Provider': (1, 0.21, 0.0), 'Haha': (1, 0.162, 0.076), 'Hemophilia': (1, 0.162, 0.076), 'Dm': (1, 0.0, 0.0), 'Breast Pumps': (1, 0.121, 0.0), 'Equipment': (1, 0.121, 0.0), 'Phone Customer Service': (1, 0.114, 0.138), 'Letter': (1, 0.171, 0.364), 'Lady': (1, 0.171, 0.364), 'Charleston': (1, 0.0, 0.2), 'Jetway': (1, 0.132, 0.0), 'Reactions': (1, 0.072, 0.128), 'Aa Ff Lxa': (1, 0.203, 0.0), 'Thansk': (1, 0.203, 0.0), 'Houston Gate ...

# %% [markdown]
# ## Final Entities

# %%
sorted_frequent_entitiy_list = sorted(frequent.items(), key=operator.itemgetter(0), reverse = True)
for i in range(0, 5):
    print("Entity: {}\t Sentiment: {}".format(sorted_frequent_entitiy_list[i][0], "postive" if sorted_frequent_entitiy_list[i][1][1] > sorted_frequent_entitiy_list[i][1][2] else "negative" ))
    print("\n")
# Out:
# Entity: the Weight Restriction	 Sentiment: negative
#
#
# Entity: the Phone Rep	 Sentiment: negative
#
#
# Entity: the Pain Fly	 Sentiment: negative
#
#
# Entity: s Sch	 Sentiment: postive
#
#
# Entity: no Info Thismosaicnothappy	 Sentiment: negative
